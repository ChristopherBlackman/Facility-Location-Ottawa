# %%
from main import test_set

# %%
test_set()
# Out:
# Extracting data from :  ./data/test0.dot
# Number Of Items :  50
# NEW CLUSTER SIZE 3
# CLUSTER SIZE 3 Iteration :  0
# Model 1
# verticies Chosen
# ['AK', 'V', 'C']
# centroid distance
# [25898.95096269 75133.37409795 69739.80091744]
# l1 norm
# 170772.125978081
# time
# 0.45836663246154785
# Model 2
# verticies Chosen
# ['AF', 'AV', 'AG']
# centroid distance
# [ 34250.83367511 192198.41132959  27541.43525588]
# l1 norm
# 253990.68026058737
# time
# 1.4103813171386719
# Model 3
# verticies Chosen
# ['B', 'T', 'AC']
# centroid distance
# [115423.5124161   51956.48217426  18651.72037615]
# l1 norm
# 186031.71496651886
# time
# 0.028910160064697266
# CLUSTER SIZE 3 Iteration :  1
# Model 1
# verticies Chosen
# ['AK', 'V', 'K']
# centroid distance
# [25898.95096269 81903.32297816 56743.64650095]
# l1 norm
# 164545.9204417999
# time
# 0.4881441593170166
# Model 2
# verticies Chosen
# ['AA', 'AD', 'AC']
# centroid distance
# [143100.08132432 191518.64526579  11363.15057   ]
# l1 norm
# ...
